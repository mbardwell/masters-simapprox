# %% [markdown]
# **Problem**:
#
# I want to approximate the non-linear data space that makes up a PyPSA simulation. Specifically, I want to approximate a modified IEEE 13 bus topology with a uniform (grid) input. The approximation should be time sensitive.
#
# **Objective**:
#
# This notebook will only look at [support vector regression](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.htmlhttps://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html) (SVR) models. Per [1], the approximation should have a root mean sqaure error < 0.002 to ensure the approximation is not the largest source of error in the simulation. A standard linear regression will be shown for baseline comparison. Since the approximation is time sensitive, a search for the ball park number of samples required for reasonable scores is performed. Once the number of samples to produce reasonable results is found, a grid search can be ran to determine optimal training parameters.
#
# **Hypothesis**:
#
# Previously, linear regression models outperformed artificial neural networks when tested on simple, small radial networks [2]. Since the modified IEEE 13 bus network contains two transformers whos behaviour can become non-linear if their power limit is exceeded (which is allowed in power flow [3]), I suspect there are two possible scenarios:
#
# 1. Transformer limit not exceeded: Linear regression outperforms RF model
# 2. Transformer limit exceeded: RF outperforms linear regressor because a RF model can capture non-linearity
#
# As for the number of samples required, historically 1e5-1e6 samples produces K-fold cross validation scores with low variance if the feature-label correlation is reasonable.
#
# **Experimental Procedure**:
#
# 1. Determine the number of samples required to return reasonable scores with SVR K-fold cross validation. Reasonable scores is defined as:
#   * R2 > 0.8
#   * RMSE < 0.002
#   * K-fold R2 variance one degree of magnitude less than R2
# 2. Using approximately that number of samples, run grid search to determine optimal parameters/hyperparameters
#
# **Results**:
#
# The model was unable to predict the first label. This is expected because the node represented by the label is a slack bus and therefore its voltage is always 1. The results for the other labels were averaged
#
# * 1e4 samples (mean R2: 0.88, std dev: 0.002)
# * 1e3 samples (mean R2: 0.87, std dev: 0.014)
# * 1e2 samples (mean R2: 0.79, std dev: 0.076)
# * 1e1 samples (mean R2: -15, std dev: 19)
#
# If the slack bus is removed the results improve by roughly 9%
#
# * 1e4 samples (mean R2: 0.96, std dev: 0.002)
# * 1e3 samples (mean R2: 0.95, std dev: 0.009)
# * 1e2 samples (mean R2: 0.87, std dev: 0.069)
# * 1e1 samples (mean R2: -16, std dev: 20)
#
# From 1e3 to 1e4 samples there is not a significant improvement in mean R2 (1%), but there is in the std dev (). From 1e2 to 1e3 it is more apparent (9%). Running a grid search with 1e3 samples produced the following results:
#
# 1. Mean R2: ? std dev: ?
# 2. Mean R2: ? std dev: ?
# 3. .
# 4. .
#
# Tried training the model on 1e5 samples for over 5 hours. Cancelled.
#
# **Discussion**:
#
# One approach to reduce the cost of simulation-based research is to copy the underlying model and evaluate the approximation [1][4].
#
# It takes roughly 7 hours to create 1e5 samples (by running PyPSA sim) on Intel(R) Xeon(R) CPU E5-2650 v4 @ 2.20GHz
#
#
# **Bibliography**
#
# [1] https://github.com/mbardwell/masters
#
# [2] Enhancing Power Flow Simulations Using Function Mapping. Michael Bardwell ; Petr Musilek. 2019 IEEE Canadian Conference on Electrical and Computer Engineering (CCECE)
#
# [3] https://groups.google.com/forum/#!searchin/pypsa/mikey%7Csort:date/pypsa/FqfC_UR85k0/vBc7HYP_EQAJ
#
# [4] ieee-13_timing-pfsim-vs-evaluating-models.ipynb
#
#
# Table of Contents:
# * Source data
# * Analyse data
# * Setup grid search

# %%
import pypsa
import time
import logging
import numpy as np
import warnings

warnings.filterwarnings('ignore')
logger = logging.getLogger("pypsa")
logger.setLevel("WARNING")
# %matplotlib inline

import copy
import csv
import sys
import time

import importlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix

import pypsa
from n_dimensional_datasets import *
from plotter import *

from IPython.display import display # for better Pandas printing

# %%
def personalise_column_names(df, name):
        new_columns = []
        for column in df.columns:
            new_columns.append(name +  "-" + str(column))
        df.columns = new_columns
        return pd.DataFrame(df)

def collect_data(path_to_powerflow_data, data):
    '''
    Assumes folder tree has
    path_to_powerflow_data/
    -->datafiles
    -->results/
    '''
    data["loads"] = personalise_column_names(pd.read_csv(path_to_powerflow_data + "loads-p_set.csv"), "load")
    data["vmags"] = personalise_column_names(pd.read_csv(path_to_powerflow_data + "results/" + "vmags.csv"), "vmag")
    data["vangs"] = personalise_column_names(pd.read_csv(path_to_powerflow_data + "results/" + "vangs.csv"), "vang")
    data["qmags"] = personalise_column_names(pd.read_csv(path_to_powerflow_data + "results/" + "qmags.csv"), "qmag")
    data["linemags"] = personalise_column_names(pd.read_csv(path_to_powerflow_data + "results/" + "linemags.csv"), "linemag")
    
import pandas as pd
import numpy as np
    
def set_uniform_sample_size(path_to_powerflow_data, data_to_change, n_samples, seed=None):
    '''
    Modifies common .csv files in PyPSA folders with uniformly sampled data 

    Parameters
    ----------
    path_to_powerflow_data: string
        ex: "/home/user/Documents/powerflow_data/"
    data_to_change: list of strings.
        ex: ["loads-p_set", "generators-p_max_pu", "snapshots"] 
    n_samples: int
    
    seed=None: int
    '''

    data = {}
    for datatype in data_to_change:
        data[datatype] = pd.read_csv(path_to_powerflow_data + datatype + ".csv")

    def increase_data(dataframe, n_samples, seed=None):
        addon = {}
        new_df_list = []
        for idx, column in enumerate(dataframe):
          
            if dataframe[column].dtype == np.float64 or dataframe[column].dtype == np.int64:
                ## special cases
                if datatype == "generators-p_max_pu":
                    # add a ridiculous amount of generation so the is always enough power and sim doesn't fail
                    addon[column] = np.random.RandomState(seed=seed).uniform(low=100, high=200, size=n_samples)
                elif datatype == "snapshots":
                    addon[column] = np.ones(n_samples)
                else:
                    addon[column] = np.random.RandomState(seed=seed).uniform(low=0, high=0.5, size=n_samples)
            elif dataframe[column].dtype == object:
                # assuming object is datetime column
                latest_datetime = pd.to_datetime(dataframe[column][0])
                addon[column] = []
                for sample in range(n_samples):
                    addon[column].append(latest_datetime + pd.Timedelta(hours=(1+sample)))
            else:
                raise TypeError("dataframe[column] type: {} should be object or float64/int64".format(
                    type(dataframe[column].dtype)))
        addon_dataframe = pd.DataFrame(addon)
        return dataframe.head(1).append(addon_dataframe)

    for datatype in data:
        data[datatype] = increase_data(data[datatype], n_samples-1, seed) # -1 is for original sample, which stays
        data[datatype].to_csv(path_to_powerflow_data + datatype + ".csv", index=False)
        print("Datatype {} stored".format(datatype))

def create_samples_and_run_network(path_to_powerflow_data, data_to_change, sample_size, seed=None):
    import os
    import shutil
    from pathlib import Path
    import pypsa

    if not os.path.isdir(path_to_powerflow_data):
        src = Path(path_to_powerflow_data).parents[0] / "ieee-13-with-load-gen/" # original modified IEEE model
        shutil.copytree(src, path_to_powerflow_data)

    set_uniform_sample_size(path_to_powerflow_data, data_to_change, sample_size, seed=None)

    network = pypsa.Network(import_name=path_to_powerflow_data)
    network.pf()

    save_path = path_to_powerflow_data + "results/"
    network.buses_t.v_mag_pu.to_csv(save_path + "vmags.csv")
    network.buses_t.v_ang.to_csv(save_path + "vangs.csv")
    network.buses_t.q.to_csv(save_path + "qmags.csv")
    network.lines_t.p0.to_csv(save_path + "linemags.csv")
    
def backup_samples(src, dest):
    '''
    thanks https://www.pythoncentral.io/how-to-recursively-copy-a-directory-folder-in-python/
    '''
    import os
    import errno
    import shutil
    
    try:
        if os.path.isdir(dest):
            shutil.rmtree(dest)
        shutil.copytree(src, dest)
        print("Backup to {} successful".format(dest))
    except OSError as e:
        # If the error was caused because the source wasn't a directory
        if e.errno == errno.ENOTDIR:
            shutil.copy(src, dest)
        else:
            print('Directory not copied. Error: %s' % e)

# %% [markdown]
# # Source Data

# %%
## USER INPUT
sample_size = 100000 # this is the max number of samples available

data_to_change = ["loads-p_set", "snapshots", "loads-q_set"]

path_to_powerflow_example = "../../pypsa/examples/ieee-13/"
path_to_powerflow_data = (path_to_powerflow_example +
                          "/ieee-13-with-load-gen-uniform-data-"
                          + str(sample_size) +
                          "-samples/")
path_to_powerflow_results = path_to_powerflow_data + "results/"

# %%
## Uncomment to generate load samples for modified IEEE-13 network
# if sample_size > 10000:
#     user = input("Are you sure [y/n]? This could erase hours worth of data")
#     if user == "y":
#         backup_samples(path_to_powerflow_results, path_to_powerflow_data + "results-backup/")
#         create_samples_and_run_network(path_to_powerflow_data, data_to_change, sample_size, seed=None)
# else:
#     create_samples_and_run_network(path_to_powerflow_data, data_to_change, sample_size, seed=None)

data = {"loads": [], "vmags": [], "vangs": [], "qmags": [], "linemags": []}
collect_data(path_to_powerflow_data, data)

# %% [markdown]
# # Analyse Data

# %%
features = data["loads"].drop("load-name", axis=1)
labels = data["vmags"].drop(["vmag-name", "vmag-Substation"], axis=1) #loc[:,["vmag-632", "vmag-671", "vmag-675"]]
features_and_labels = features.join(labels)

# %%
features.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9a760cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bc89f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bc496d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bbfaed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bbb6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bbe5f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bba3750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bb53f50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9bb5bb10>]],
#       dtype=object)

# %%
labels.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9a760ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9b116090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9b068710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9b099f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9b05a750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9b00ef50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9afcf790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9af82f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9af8eb50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9af50510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9aebd810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9ae7a210>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9ae2cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9ae5fc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9ae1ffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f8c9add3c50>]],
#       dtype=object)

# %%
corr_matrix = labels.join(features).corr()

# only loads for columns
cols = [c for i, c in enumerate(corr_matrix.columns) if corr_matrix.keys().str.contains("^load", regex=True)[i]]
reduced_corr_matrix = corr_matrix[cols]
reduced_corr_matrix["row average"] = pd.Series(reduced_corr_matrix.mean(axis=1))
# only voltages for rows
rows = reduced_corr_matrix.index[reduced_corr_matrix.index.str.contains("load")]
reduced_corr_matrix.drop(rows, inplace=True)
reduced_corr_matrix = reduced_corr_matrix.append(pd.Series(reduced_corr_matrix.mean(), name="column average"))

display(reduced_corr_matrix)
# Out:
#                 load-632  load-634  load-645  load-646  load-652  load-671  \
# vmag-650       -0.008439  0.001458 -0.002953 -0.000081 -0.001955 -0.007134
# vmag-646       -0.196512 -0.200144 -0.487273 -0.671172 -0.211606 -0.204674
# vmag-645       -0.219407 -0.223990 -0.546822 -0.558979 -0.235927 -0.229190
# vmag-632       -0.316812 -0.320804 -0.319882 -0.333944 -0.339195 -0.329811
# vmag-633       -0.286406 -0.512513 -0.289868 -0.302645 -0.307178 -0.298881
# vmag-634       -0.286326 -0.512387 -0.289801 -0.302548 -0.307111 -0.298800
# vmag-611       -0.157880 -0.158084 -0.155850 -0.168281 -0.463138 -0.316864
# vmag-684       -0.170285 -0.171447 -0.168631 -0.182151 -0.502244 -0.343257
# vmag-671       -0.196724 -0.199334 -0.196651 -0.210183 -0.410146 -0.399117
# vmag-692       -0.196689 -0.199299 -0.196616 -0.210148 -0.410075 -0.399049
# vmag-675       -0.187323 -0.189802 -0.187164 -0.200840 -0.391617 -0.380550
# vmag-652       -0.140446 -0.141170 -0.137119 -0.151906 -0.698675 -0.281787
# vmag-680       -0.196724 -0.199334 -0.196651 -0.210183 -0.410146 -0.399117
# column average -0.196921 -0.232835 -0.244252 -0.269466 -0.360693 -0.299095
#
#                 load-675  load-692  load-611  row average
# vmag-650       -0.001353 -0.004306 -0.001971    -0.002970
# vmag-646       -0.199273 -0.208235 -0.211118    -0.287779
# vmag-645       -0.223332 -0.233060 -0.236599    -0.300812
# vmag-632       -0.324215 -0.334387 -0.339914    -0.328774
# vmag-633       -0.292050 -0.303695 -0.307554    -0.322310
# vmag-634       -0.291940 -0.303616 -0.307463    -0.322221
# vmag-611       -0.313902 -0.320260 -0.600170    -0.294936
# vmag-684       -0.340429 -0.346904 -0.501052    -0.302933
# vmag-671       -0.395772 -0.403272 -0.410221    -0.313491
# vmag-692       -0.395916 -0.403413 -0.410151    -0.313484
# vmag-675       -0.479096 -0.385147 -0.391644    -0.310354
# vmag-652       -0.280290 -0.284874 -0.411965    -0.280915
# vmag-680       -0.395772 -0.403272 -0.410221    -0.313491
# column average -0.302565 -0.302649 -0.349234    -0.284190

# %% [markdown]
# # Setup Models

# %%
import csv
import datetime

from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate, cross_val_predict
from sklearn.metrics import r2_score, make_scorer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from scoring import rmse

# %%
def set_data_size(n_samples, n_training_samples):
    X_train, X_val, y_train, y_val, test_idx, train_idx = train_test_split(features,
                                                                           labels,
                                                                           range(features.shape[0]),
                                                                           train_size=n_training_samples,
                                                                           test_size=n_samples-n_training_samples,
                                                                           random_state=None)
    X_train = X_train.values
    y_train = y_train.values
    X_val = X_val.values
    y_val = y_val.values

    return X_train, y_train, X_val, y_val

# %% [markdown]
# # Determine number of samples to get reasonable scores

# %%
# setup model parameters/hyperparameters

'''
dnn hyperparameters are chosen from sandbox testing. On average the model attempts to converge 
(with other parameters it sometimes gives up early).
'''
svr = SVR(gamma='scale', C=1.0, epsilon=0.0002, kernel='rbf')

linear = LinearRegression()

# %%
svr_xval_scores = []
linear_xval_scores = []
for i, n_samples in enumerate([100, 1000, 10000, 100000]):
    current_iteration = i

    n_training_samples = int(n_samples*(80/100))
    X_train, y_train, X_val, y_val = set_data_size(n_samples, n_training_samples)

    print("\n\nRun: ", current_iteration)
    print("n_training_samples: ", n_training_samples)
    print("n_validation_samples: ", n_samples-n_training_samples)
    print("n_features: ", X_train.shape[1])
    print("n_labels: ", y_train.shape[1])

    ## svr - can only predict one label at a time
    print("\n\nSVR\n\n")
    
    time_start = time.time()
    svr_models = []
    for label in range(y_train.shape[1]):
        svr_y_train = y_train.T[label].T
        svr_xval_scores = pd.DataFrame(cross_validate(svr, 
                                                      X_train, 
                                                      svr_y_train, 
                                                      cv=5, 
                                                      n_jobs=-1, 
                                                      scoring=make_scorer(r2_score)))
        svr_xval_scores.columns = [col + "_label_" + str(label) for col in svr_xval_scores.columns]
        if label == 0:
            svr_results = svr_xval_scores
        else:
            svr_results = svr_results.join(svr_xval_scores)
        
        svr_models.append(svr.fit(X_train, svr_y_train))

    time_svr = time.time()
    print("cross validation training time {:.5}".format(time_svr-time_start))
    print("cross validation training scores: ")
    display(svr_results)

    print("non-cross validation model scores for reference:")
    for label in range(y_train.shape[1]):
        print("label: ", label)
        print("training score: ", r2_score(y_train.T[label].T, svr.predict(X_train)))
        print("validation score: ", r2_score(y_val.T[label].T, svr.predict(X_val)))
        print("rmse: ", rmse(y_val.T[label].T, svr.predict(X_val)))

    ## linear regression
    print("\n\nLINEAR REGRESSION\n\n")
    time_start = time.time()
    linear_xval_scores.append(cross_validate(linear,
                                             X_train,
                                             y_train,
                                             cv=5,
                                             n_jobs=-1,
                                             scoring=make_scorer(r2_score)))

    time_linear = time.time()
    print("cross validation training time {:.5}".format(time_linear-time_start))
    print("cross validation training scores: ")
    linear_results = pd.DataFrame(linear_xval_scores[current_iteration])
    linear_results.columns = ["linear_"+col for col in linear_results.columns]
    display(linear_results)

    linear.fit(X_train, y_train)
    print("non-cross validation model scores for reference:")
    print("training score: ", r2_score(y_train, linear.predict(X_train)))
    print("validation score: ", r2_score(y_val, linear.predict(X_val)))
    print("rmse: ", rmse(linear.predict(X_val), y_val))

    ## model statistics
    datetimestamp = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")
    results_to_save = linear_results.join(svr_results).round(3)
    results_to_save.to_csv(path_to_powerflow_data + 
                           "/results/approximating_with_svr_results-{}_samples-{}.csv".format(n_samples, 
                                                                                             datetimestamp))
# Out:
# Run:  0
# n_training_samples:  80
# n_validation_samples:  20
# n_features:  9
# n_labels:  13
#
#
# SVR
#
#
# cross validation training time 0.33906
# cross validation training scores:
#    fit_time_label_0  score_time_label_0  test_score_label_0  fit_time_label_1  \
# 0          0.001367            0.000628           -0.404138          0.000908
# 1          0.030785            0.000973           -0.138660          0.000912
# 2          0.001328            0.000656           -0.061851          0.000711
# 3          0.001519            0.000801           -0.172559          0.000712
# 4          0.000540            0.000441           -0.006380          0.000839
#
#    score_time_label_1  test_score_label_1  fit_time_label_2  \
# 0            0.000521            0.881090          0.000912
# 1            0.000502            0.940861          0.000780
# 2            0.000480            0.918889          0.000669
# 3            0.000491            0.929882          0.000565
# 4            0.000594            0.770056          0.000559
#
#    score_time_label_2  test_score_label_2  fit_time_label_3  ...  \
# 0            0.000601            0.902811          0.000664  ...
# 1            0.000466            0.941230          0.000708  ...
# 2            0.000434            0.931277          0.000601  ...
# 3            0.000415            0.926467          0.000574  ...
# 4            0.000442            0.776781          0.000539  ...
#
#    test_score_label_9  fit_time_label_10  score_time_label_10  \
# 0            0.767919           0.000629             0.000437
# 1            0.937353           0.000651             0.000432
# 2            0.925586           0.000611             0.000425
# 3            0.895069           0.000569             0.000430
# 4            0.802709           0.000594             0.000412
#
#    test_score_label_10  fit_time_label_11  score_time_label_11  \
# 0             0.766022           0.000663             0.000442
# 1             0.936000           0.000741             0.000477
# 2             0.920585           0.000711             0.000489
# 3             0.894911           0.000623             0.000433
# 4             0.794008           0.000604             0.000433
#
#    test_score_label_11  fit_time_label_12  score_time_label_12  \
# 0             0.771251           0.000659             0.000434
# 1             0.937015           0.000650             0.000463
# 2             0.918964           0.000597             0.000409
# 3             0.856707           0.023688             0.000560
# 4             0.847214           0.000777             0.000524
#
#    test_score_label_12
# 0             0.767909
# 1             0.937355
# 2             0.925600
# 3             0.895062
# 4             0.802676
#
# [5 rows x 39 columns]
# non-cross validation model scores for reference:
# label:  0
# training score:  -398891.1983399248
# validation score:  -368276.3536812776
# rmse:  0.05546627698395137
# label:  1
# training score:  0.5736464958564393
# validation score:  0.21199693282003174
# rmse:  0.007551526085124966
# label:  2
# training score:  0.2948369491754753
# validation score:  -0.5077203291707015
# rmse:  0.009020238977857383
# label:  3
# training score:  -7.859667987796241
# validation score:  -14.365136360019951
# rmse:  0.01892231492999851
# label:  4
# training score:  -4.298954723704377
# validation score:  -6.0733882511091
# rmse:  0.015525147125494984
# label:  5
# training score:  -4.253317115079584
# validation score:  -6.023302260185082
# rmse:  0.015468948687056944
# label:  6
# training score:  0.25464384942409357
# validation score:  -0.7923164901690274
# rmse:  0.014022642096046896
# label:  7
# training score:  0.6054600142662074
# validation score:  -0.13975106261606962
# rmse:  0.01019671004289791
# label:  8
# training score:  0.9984774240967816
# validation score:  0.7484365993282376
# rmse:  0.003966805698581141
# label:  9
# training score:  0.9984763405391334
# validation score:  0.7480176151248412
# rmse:  0.00397056810646142
# label:  10
# training score:  0.9631820132345752
# validation score:  0.5828815371314042
# rmse:  0.005119020085081781
# label:  11
# training score:  -0.3548501120890517
# validation score:  -1.355230031028229
# rmse:  0.018992550595235275
# label:  12
# training score:  0.9984774240967815
# validation score:  0.7484365993282367
# rmse:  0.0039668056985811585
#
#
# LINEAR REGRESSION
#
#
# cross validation training time 0.012639
# cross validation training scores:
#    linear_fit_time  linear_score_time  linear_test_score
# 0         0.001755           0.000474           0.860111
# 1         0.001018           0.000420           0.906727
# 2         0.000563           0.000378           0.895310
# 3         0.000551           0.000375           0.882817
# 4         0.000560           0.000400           0.845123
# non-cross validation model scores for reference:
# training score:  0.9137280358009785
# validation score:  0.8674069049458768
# rmse:  0.001646198179553289
#
#
# Run:  1
# n_training_samples:  800
# n_validation_samples:  200
# n_features:  9
# n_labels:  13
#
#
# SVR
#
#
# cross validation training time 6.8781
# cross validation training scores:
#    fit_time_label_0  score_time_label_0  test_score_label_0  fit_time_label_1  \
# 0          0.001030            0.000656           -0.041337          0.224496
# 1          0.000714            0.000559           -0.161251          0.120450
# 2          0.001593            0.000464           -0.023947          0.147391
# 3          0.000955            0.000689           -0.152011          0.223858
# 4          0.000805            0.000441           -0.011250          0.151633
#
#    score_time_label_1  test_score_label_1  fit_time_label_2  \
# 0            0.004013            0.961345          0.174110
# 1            0.009422            0.960614          0.105753
# 2            0.039989            0.942821          0.127923
# 3            0.003908            0.962616          0.166143
# 4            0.004563            0.950752          0.127154
#
#    score_time_label_2  test_score_label_2  fit_time_label_3  ...  \
# 0            0.004127            0.958765          0.098003  ...
# 1            0.003833            0.959537          0.180407  ...
# 2            0.028219            0.941702          0.140484  ...
# 3            0.017381            0.962554          0.121875  ...
# 4            0.013142            0.948683          0.064667  ...
#
#    test_score_label_9  fit_time_label_10  score_time_label_10  \
# 0            0.956391           0.187610             0.004374
# 1            0.961784           0.237476             0.004564
# 2            0.944901           0.296333             0.029478
# 3            0.963718           0.232661             0.013601
# 4            0.945887           0.138421             0.008377
#
#    test_score_label_10  fit_time_label_11  score_time_label_11  \
# 0             0.957396           0.230689             0.016093
# 1             0.962050           0.166790             0.004499
# 2             0.947705           0.225302             0.049461
# 3             0.964819           0.134406             0.044381
# 4             0.948549           0.176385             0.005634
#
#    test_score_label_11  fit_time_label_12  score_time_label_12  \
# 0             0.955812           0.167104             0.012935
# 1             0.962031           0.201628             0.005284
# 2             0.947311           0.153859             0.004582
# 3             0.961410           0.157701             0.005725
# 4             0.944803           0.124232             0.024353
#
#    test_score_label_12
# 0             0.956311
# 1             0.962187
# 2             0.945782
# 3             0.963396
# 4             0.946977
#
# [5 rows x 39 columns]
# non-cross validation model scores for reference:
# label:  0
# training score:  -404598.9390780738
# validation score:  -414598.1517789576
# rmse:  0.05410832875613987
# label:  1
# training score:  0.41665275733875473
# validation score:  0.34057648821372266
# rmse:  0.008793927420683278
# label:  2
# training score:  0.03057768184307008
# validation score:  -0.06533633217975354
# rmse:  0.009897571728430197
# label:  3
# training score:  -7.540752585911884
# validation score:  -7.862868910864115
# rmse:  0.019444544043972015
# label:  4
# training score:  -4.070310623558734
# validation score:  -4.326539462361496
# rmse:  0.016547564785426013
# label:  5
# training score:  -4.039441078929949
# validation score:  -4.290228174341879
# rmse:  0.01649477922679165
# label:  6
# training score:  0.3445295159026497
# validation score:  0.27008820626569174
# rmse:  0.011205536007669513
# label:  7
# training score:  0.6606542480072028
# validation score:  0.5995833597282114
# rmse:  0.00762957691840547
# label:  8
# training score:  0.9987645986340599
# validation score:  0.9537835232829734
# rmse:  0.002254259208172381
# label:  9
# training score:  0.9987618864010832
# validation score:  0.9538270738899316
# rmse:  0.0022536539240751554
# label:  10
# training score:  0.9665276953329598
# validation score:  0.9285787071014735
# rmse:  0.0029572001994204685
# label:  11
# training score:  -0.1314331523575023
# validation score:  -0.3139679762578147
# rmse:  0.016630529664628545
# label:  12
# training score:  0.9987645986340599
# validation score:  0.9537835232829734
# rmse:  0.0022542592081723815
#
#
# LINEAR REGRESSION
#
#
# cross validation training time 0.064565
# cross validation training scores:
#    linear_fit_time  linear_score_time  linear_test_score
# 0         0.002637           0.000549           0.906108
# 1         0.002035           0.000550           0.903111
# 2         0.001780           0.000544           0.904385
# 3         0.001600           0.000489           0.903627
# 4         0.001248           0.000495           0.899888
# non-cross validation model scores for reference:
# training score:  0.9077665845281383
# validation score:  0.9048806366132508
# rmse:  0.0013710857936568197
#
#
# Run:  2
# n_training_samples:  8000
# n_validation_samples:  2000
# n_features:  9
# n_labels:  13
#
#
# SVR

# %% [markdown]
# # Importing results for calculating mean/std
#
# This is different than the RF/DNN notebooks because there are more numbers to crunch

# %%
def mean_and_std(results_dataframe, label_min):
    scores = imported_results.loc[:,["test_score_label_" + str(i) for i in range(label_min,13)]]
    means = scores.mean()
    stds = scores.std()
    the_mean = np.mean(means)
    the_std = np.mean(stds)
    print("mean: {:.5} std: {:.5} for labels from {} to 12".format(the_mean, the_std, label_min))


imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-10000_samples-2019-09-12-00-21.csv")
imported_results_hold1 = imported_results
mean_and_std(imported_results, 0)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-1000_samples-2019-09-11-23-22.csv")
imported_results_hold2 = imported_results
mean_and_std(imported_results, 0)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-100_samples-2019-09-11-23-22.csv")
mean_and_std(imported_results, 0)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-10_samples-2019-09-11-23-20.csv")
mean_and_std(imported_results, 0)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-10000_samples-2019-09-12-00-21.csv")
mean_and_std(imported_results, 1)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-1000_samples-2019-09-11-23-22.csv")
mean_and_std(imported_results, 1)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-100_samples-2019-09-11-23-22.csv")
mean_and_std(imported_results, 1)

imported_results = pd.read_csv(path_to_powerflow_data + "results/" + 
            "approximating_with_svr_results-10_samples-2019-09-11-23-20.csv")
mean_and_std(imported_results, 1)

display(imported_results_hold1)
display(imported_results_hold2)
# Out:
# mean: 0.88242 std: 0.0019049 for labels from 0 to 12
# mean: 0.87425 std: 0.013803 for labels from 0 to 12
# mean: 0.7944 std: 0.075523 for labels from 0 to 12
# mean: -14.923 std: 18.887 for labels from 0 to 12
# mean: 0.95605 std: 0.0019939 for labels from 1 to 12
# mean: 0.95358 std: 0.0088948 for labels from 1 to 12
# mean: 0.87367 std: 0.069082 for labels from 1 to 12
# mean: -15.676 std: 19.772 for labels from 1 to 12
#    Unnamed: 0  linear_fit_time  linear_score_time  linear_test_score  \
# 0           0            0.010              0.001              0.905
# 1           1            0.010              0.001              0.906
# 2           2            0.016              0.002              0.906
# 3           3            0.009              0.001              0.905
# 4           4            0.006              0.001              0.905
#
#    fit_time_label_0  score_time_label_0  test_score_label_0  fit_time_label_1  \
# 0             0.004               0.001              -0.000           162.387
# 1             0.003               0.001              -0.001           159.017
# 2             0.003               0.001              -0.002           163.874
# 3             0.003               0.001              -0.001           163.062
# 4             0.002               0.001              -0.002            96.826
#
#    score_time_label_1  test_score_label_1  ...  test_score_label_9  \
# 0               1.073               0.961  ...               0.960
# 1               0.999               0.956  ...               0.957
# 2               0.829               0.962  ...               0.956
# 3               0.941               0.957  ...               0.956
# 4               0.651               0.959  ...               0.958
#
#    fit_time_label_10  score_time_label_10  test_score_label_10  \
# 0             68.145                0.441                0.961
# 1             68.869                0.444                0.959
# 2             68.181                0.431                0.957
# 3             68.627                0.449                0.957
# 4             67.617                0.483                0.959
#
#    fit_time_label_11  score_time_label_11  test_score_label_11  \
# 0             67.372                0.433                0.964
# 1             65.471                0.436                0.963
# 2             67.798                0.445                0.961
# 3             67.603                0.449                0.961
# 4             67.553                0.454                0.963
#
#    fit_time_label_12  score_time_label_12  test_score_label_12
# 0             70.088                0.460                0.959
# 1             67.659                0.419                0.957
# 2             69.363                0.530                0.956
# 3             68.765                0.535                0.956
# 4             68.641                0.433                0.958
#
# [5 rows x 43 columns]
#    Unnamed: 0  linear_fit_time  linear_score_time  linear_test_score  \
# 0           0            0.003              0.001              0.906
# 1           1            0.002              0.001              0.903
# 2           2            0.002              0.001              0.904
# 3           3            0.002              0.000              0.904
# 4           4            0.001              0.000              0.900
#
#    fit_time_label_0  score_time_label_0  test_score_label_0  fit_time_label_1  \
# 0             0.001               0.001              -0.041             0.224
# 1             0.001               0.001              -0.161             0.120
# 2             0.002               0.000              -0.024             0.147
# 3             0.001               0.001              -0.152             0.224
# 4             0.001               0.000              -0.011             0.152
#
#    score_time_label_1  test_score_label_1  ...  test_score_label_9  \
# 0               0.004               0.961  ...               0.956
# 1               0.009               0.961  ...               0.962
# 2               0.040               0.943  ...               0.945
# 3               0.004               0.963  ...               0.964
# 4               0.005               0.951  ...               0.946
#
#    fit_time_label_10  score_time_label_10  test_score_label_10  \
# 0              0.188                0.004                0.957
# 1              0.237                0.005                0.962
# 2              0.296                0.029                0.948
# 3              0.233                0.014                0.965
# 4              0.138                0.008                0.949
#
#    fit_time_label_11  score_time_label_11  test_score_label_11  \
# 0              0.231                0.016                0.956
# 1              0.167                0.004                0.962
# 2              0.225                0.049                0.947
# 3              0.134                0.044                0.961
# 4              0.176                0.006                0.945
#
#    fit_time_label_12  score_time_label_12  test_score_label_12
# 0              0.167                0.013                0.956
# 1              0.202                0.005                0.962
# 2              0.154                0.005                0.946
# 3              0.158                0.006                0.963
# 4              0.124                0.024                0.947
#
# [5 rows x 43 columns]

# %% [markdown]
# # Search

# %%
from sklearn.model_selection import RandomizedSearchCV
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 600)

# %%
n_samples = 10000
if n_samples < 10000:
    raise ValueError("So you don't accidentally run this on 100 samples again")
n_training_samples = int(n_samples*(80/100))
X_train, y_train, X_val, y_val = set_data_size(n_samples, n_training_samples)

# %%
svr = SVR()
params = {"gamma": ["auto", "scale"], 
          "C": [i*5/1000 for i in range(0,1000)], # min: 0, max: 5
          "epsilon": [i*2/1000000 for i in range(1,1000)], # min: 2e-6, max: 2e-3
          "kernel": ["rbf", "poly", "sigmoid", "linear"],
          "tol": [i/1000000 for i in range(1, 1000)] # min: 1e-6, max: 1e-3
         }


for label in range(1, y_train.shape[1]):
    svr_y_train = y_train.T[label].T

    grid = RandomizedSearchCV(svr, params, cv=5, n_iter=30, n_jobs=-1, refit=False,
                      scoring={"r2": make_scorer(r2_score), "rmse": make_scorer(rmse)}, iid=False, verbose=10)

    grid.fit(X_train, svr_y_train)

    print("\n\nSVR\n\n")
    grid_results = pd.DataFrame(grid.cv_results_)
    display(grid_results.sort_values(by=["rank_test_r2"]))
    datetimestamp = datetime.datetime.now().strftime("%Y-%m-%d-%H-%M")
    filepath = (path_to_powerflow_data + 
                "/results/approximating_with_svr_grid_results-{}_samples-{}_label-{}.csv".format(
                    n_samples, datetimestamp, label))
    print("Saving to ", filepath)
    grid_results.to_csv(filepath)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:   16.8s
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   16.9s
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:   17.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1820s.) Setting batch_size=2.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:   17.2s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1097s.) Setting batch_size=6.
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.1327s.) Setting batch_size=18.
# [Parallel(n_jobs=-1)]: Done 127 out of 150 | elapsed:   18.0s remaining:    3.3s
# SVR
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  1.2min finished
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_tol  \
# 18       0.061229      0.022771         0.012859        0.010149   0.00269
# 16       0.029265      0.022243         0.016066        0.025153   0.00423
# 17       0.009376      0.003584         0.005206        0.003319   0.00358
# 13       0.002232      0.000130         0.007313        0.006814   0.00746
# 25       0.001994      0.000304         0.003895        0.003135   0.00884
# 4        0.003946      0.001870         0.001755        0.000112   0.00847
# 14       0.002109      0.000115         0.003895        0.004825   0.00497
# 22       0.005516      0.006974         0.001586        0.000191    0.0031
# 20       0.014956      0.023139         0.001541        0.000074   0.00036
# 15       0.008147      0.012492         0.003112        0.003259   0.00456
# 29       0.011001      0.018800         0.001519        0.000074   0.00464
# 11       0.015598      0.026962         0.001608        0.000095   0.00628
# 23       0.001395      0.000073         0.002801        0.002611   0.00381
# 21       0.001729      0.000207         0.009607        0.012333   0.00292
# 10       0.004184      0.004860         0.002162        0.001418   0.00232
# 19       0.010274      0.007834         0.001555        0.000091   0.00673
# 5        0.002164      0.000102         0.011168        0.015565   0.00832
# 3        0.004164      0.004197         0.009416        0.009444    0.0016
# 7        0.003185      0.000837         0.001559        0.000060   0.00622
# 9        0.002410      0.000191         0.006386        0.005911   0.00468
# 12       0.002823      0.000508         0.010735        0.010736   0.00963
# 6        0.005990      0.007266         0.001834        0.000573   0.00733
# 28       0.002313      0.000136         0.001555        0.000016   0.00061
# 26       0.001494      0.000099         0.003076        0.003252   0.00722
# 8        0.005168      0.004429         0.004264        0.005041   0.00551
# 2        0.002362      0.000198         0.007056        0.010082   0.00231
# 24       0.004800      0.006522         0.003374        0.003068   0.00261
# 1        0.002528      0.000193         0.001618        0.000087   0.00257
# 27       7.878100      0.362834         2.652672        0.057703   0.00388
# 0       10.364204      0.478791         3.468197        0.342519   0.00601
#
#    param_kernel param_gamma param_epsilon param_C  \
# 18          rbf       scale        0.0112   1.345
# 16         poly        auto         0.011    3.66
# 17          rbf       scale        0.0234    2.74
# 13      sigmoid        auto        0.0256   3.315
# 25       linear        auto        0.0274    1.29
# 4           rbf       scale        0.0286   1.385
# 14      sigmoid       scale        0.1096   0.005
# 22          rbf       scale        0.1158   2.885
# 20         poly        auto        0.1622   3.745
# 15      sigmoid       scale        0.1098     2.9
# 29       linear        auto        0.1158    4.07
# 11          rbf        auto        0.1054    2.76
# 23       linear        auto        0.0776    3.86
# 21       linear       scale        0.1416   0.015
# 10         poly        auto        0.0434    3.49
# 19         poly        auto        0.0406    2.22
# 5        linear       scale        0.0512   2.365
# 3          poly        auto        0.0794    0.12
# 7           rbf       scale        0.1558   2.695
# 9       sigmoid       scale        0.0448    4.99
# 12      sigmoid       scale        0.0314    2.09
# 6           rbf        auto        0.0616   1.275
# 28      sigmoid        auto        0.1604   0.635
# 26         poly        auto        0.1764   3.695
# 8        linear       scale        0.1532   0.945
# 2       sigmoid        auto        0.1856    2.74
# 24         poly        auto        0.1976   2.015
# 1        linear       scale        0.1146   3.455
# 27      sigmoid       scale          0.02   0.155
# 0       sigmoid       scale        0.0174   0.175
#
#                                                params  split0_test_r2  \
# 18  {'tol': 0.00269, 'kernel': 'rbf', 'gamma': 'sc...        0.872245
# 16  {'tol': 0.00423, 'kernel': 'poly', 'gamma': 'a...        0.716859
# 17  {'tol': 0.00358, 'kernel': 'rbf', 'gamma': 'sc...        0.375936
# 13  {'tol': 0.00746, 'kernel': 'sigmoid', 'gamma':...        0.282210
# 25  {'tol': 0.00884, 'kernel': 'linear', 'gamma': ...        0.208940
# 4   {'tol': 0.00847, 'kernel': 'rbf', 'gamma': 'sc...       -0.003500
# 14  {'tol': 0.00497, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 22  {'tol': 0.0031, 'kernel': 'rbf', 'gamma': 'sca...       -0.003500
# 20  {'tol': 0.00036, 'kernel': 'poly', 'gamma': 'a...       -0.003500
# 15  {'tol': 0.00456, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 29  {'tol': 0.00464, 'kernel': 'linear', 'gamma': ...       -0.003500
# 11  {'tol': 0.00628, 'kernel': 'rbf', 'gamma': 'au...       -0.003500
# 23  {'tol': 0.00381, 'kernel': 'linear', 'gamma': ...       -0.003500
# 21  {'tol': 0.00292, 'kernel': 'linear', 'gamma': ...       -0.003500
# 10  {'tol': 0.00232, 'kernel': 'poly', 'gamma': 'a...       -0.003500
# 19  {'tol': 0.00673, 'kernel': 'poly', 'gamma': 'a...       -0.003500
# 5   {'tol': 0.00832, 'kernel': 'linear', 'gamma': ...       -0.003500
# 3   {'tol': 0.0016, 'kernel': 'poly', 'gamma': 'au...       -0.003500
# 7   {'tol': 0.00622, 'kernel': 'rbf', 'gamma': 'sc...       -0.003500
# 9   {'tol': 0.00468, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 12  {'tol': 0.00963, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 6   {'tol': 0.00733, 'kernel': 'rbf', 'gamma': 'au...       -0.003500
# 28  {'tol': 0.00061, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 26  {'tol': 0.00722, 'kernel': 'poly', 'gamma': 'a...       -0.003500
# 8   {'tol': 0.00551, 'kernel': 'linear', 'gamma': ...       -0.003500
# 2   {'tol': 0.00231, 'kernel': 'sigmoid', 'gamma':...       -0.003500
# 24  {'tol': 0.00261, 'kernel': 'poly', 'gamma': 'a...       -0.003500
# 1   {'tol': 0.00257, 'kernel': 'linear', 'gamma': ...       -0.003500
# 27  {'tol': 0.00388, 'kernel': 'sigmoid', 'gamma':...  -609859.742179
# 0   {'tol': 0.00601, 'kernel': 'sigmoid', 'gamma':...  -777319.115486
#
#     split1_test_r2  split2_test_r2  split3_test_r2  split4_test_r2  \
# 18        0.853641        0.857719        0.869901        0.865814
# 16        0.736490        0.736235        0.682415        0.651500
# 17        0.385746        0.363594        0.415484        0.412634
# 13        0.351888        0.347217        0.350878        0.350149
# 25        0.277699        0.273985        0.278183        0.277017
# 4         0.099159        0.119026        0.113035        0.105941
# 14       -0.013133       -0.006917       -0.004917       -0.008691
# 22       -0.013133       -0.006917       -0.004917       -0.008691
# 20       -0.013133       -0.006917       -0.004917       -0.008691
# 15       -0.013133       -0.006917       -0.004917       -0.008691
# 29       -0.013133       -0.006917       -0.004917       -0.008691
# 11       -0.013133       -0.006917       -0.004917       -0.008691
# 23       -0.013133       -0.006917       -0.004917       -0.008691
# 21       -0.013133       -0.006917       -0.004917       -0.008691
# 10       -0.013133       -0.006917       -0.004917       -0.008691
# 19       -0.013133       -0.006917       -0.004917       -0.008691
# 5        -0.013133       -0.006917       -0.004917       -0.008691
# 3        -0.013133       -0.006917       -0.004917       -0.008691
# 7        -0.013133       -0.006917       -0.004917       -0.008691
# 9        -0.013133       -0.006917       -0.004917       -0.008691
# 12       -0.013133       -0.006917       -0.004917       -0.008691
# 6        -0.013133       -0.006917       -0.004917       -0.008691
# 28       -0.013133       -0.006917       -0.004917       -0.008691
# 26       -0.013133       -0.006917       -0.004917       -0.008691
# 8        -0.013133       -0.006917       -0.004917       -0.008691
# 2        -0.013133       -0.006917       -0.004917       -0.008691
# 24       -0.013133       -0.006917       -0.004917       -0.008691
# 1        -0.013133       -0.006917       -0.004917       -0.008691
# 27  -656890.229369  -650398.207282  -631825.932342  -668554.151324
# 0   -837167.011879  -828924.896943  -805232.127391  -852181.150427
#
#      mean_test_r2   std_test_r2  rank_test_r2  split0_test_rmse  \
# 18       0.863864      0.007110             1          0.003880
# 16       0.704700      0.033105             2          0.005776
# 17       0.390679      0.020360             3          0.008575
# 13       0.336468      0.027174             4          0.009197
# 25       0.263165      0.027152             5          0.009655
# 4        0.086732      0.045607             6          0.010874
# 14      -0.007432      0.003351             7          0.010874
# 22      -0.007432      0.003351             7          0.010874
# 20      -0.007432      0.003351             7          0.010874
# 15      -0.007432      0.003351             7          0.010874
# 29      -0.007432      0.003351             7          0.010874
# 11      -0.007432      0.003351            12          0.010874
# 23      -0.007432      0.003351            12          0.010874
# 21      -0.007432      0.003351            12          0.010874
# 10      -0.007432      0.003351            12          0.010874
# 19      -0.007432      0.003351            12          0.010874
# 5       -0.007432      0.003351            12          0.010874
# 3       -0.007432      0.003351            12          0.010874
# 7       -0.007432      0.003351            12          0.010874
# 9       -0.007432      0.003351            12          0.010874
# 12      -0.007432      0.003351            12          0.010874
# 6       -0.007432      0.003351            12          0.010874
# 28      -0.007432      0.003351            23          0.010874
# 26      -0.007432      0.003351            23          0.010874
# 8       -0.007432      0.003351            25          0.010874
# 2       -0.007432      0.003351            25          0.010874
# 24      -0.007432      0.003351            25          0.010874
# 1       -0.007432      0.003351            25          0.010874
# 27 -643505.652499  20603.614474            29          8.477242
# 0  -820164.860425  26266.322904            30          9.570600
#
#     split1_test_rmse  split2_test_rmse  split3_test_rmse  split4_test_rmse  \
# 18          0.004076          0.004057          0.003871          0.003900
# 16          0.005469          0.005524          0.006048          0.006286
# 17          0.008351          0.008580          0.008205          0.008160
# 13          0.008578          0.008690          0.008647          0.008584
# 25          0.009055          0.009165          0.009118          0.009054
# 4           0.010113          0.010095          0.010108          0.010068
# 14          0.010724          0.010793          0.010759          0.010694
# 22          0.010724          0.010793          0.010759          0.010694
# 20          0.010724          0.010793          0.010759          0.010694
# 15          0.010724          0.010793          0.010759          0.010694
# 29          0.010724          0.010793          0.010759          0.010694
# 11          0.010724          0.010793          0.010759          0.010694
# 23          0.010724          0.010793          0.010759          0.010694
# 21          0.010724          0.010793          0.010759          0.010694
# 10          0.010724          0.010793          0.010759          0.010694
# 19          0.010724          0.010793          0.010759          0.010694
# 5           0.010724          0.010793          0.010759          0.010694
# 3           0.010724          0.010793          0.010759          0.010694
# 7           0.010724          0.010793          0.010759          0.010694
# 9           0.010724          0.010793          0.010759          0.010694
# 12          0.010724          0.010793          0.010759          0.010694
# 6           0.010724          0.010793          0.010759          0.010694
# 28          0.010724          0.010793          0.010759          0.010694
# 26          0.010724          0.010793          0.010759          0.010694
# 8           0.010724          0.010793          0.010759          0.010694
# 2           0.010724          0.010793          0.010759          0.010694
# 24          0.010724          0.010793          0.010759          0.010694
# 1           0.010724          0.010793          0.010759          0.010694
# 27          8.635535          8.674237          8.530947          8.706211
# 0           9.748748          9.792625          9.630725          9.829395
#
#     mean_test_rmse  std_test_rmse  rank_test_rmse
# 18        0.003957       0.000090              30
# 16        0.005821       0.000310              29
# 17        0.008374       0.000178              28
# 13        0.008739       0.000233              27
# 25        0.009209       0.000227              26
# 4         0.010252       0.000312              25
# 14        0.010769       0.000062              20
# 22        0.010769       0.000062              20
# 20        0.010769       0.000062              20
# 15        0.010769       0.000062              20
# 29        0.010769       0.000062              20
# 11        0.010769       0.000062               7
# 23        0.010769       0.000062               7
# 21        0.010769       0.000062               7
# 10        0.010769       0.000062               7
# 19        0.010769       0.000062               7
# 5         0.010769       0.000062               7
# 3         0.010769       0.000062               7
# 7         0.010769       0.000062               7
# 9         0.010769       0.000062               7
# 12        0.010769       0.000062               7
# 6         0.010769       0.000062               7
# 28        0.010769       0.000062               7
# 26        0.010769       0.000062               7
# 8         0.010769       0.000062               3
# 2         0.010769       0.000062               3
# 24        0.010769       0.000062               3
# 1         0.010769       0.000062               3
# 27        8.604834       0.086920               2
# 0         9.714419       0.098186               1
# Saving to  ../../pypsa/examples/ieee-13//ieee-13-with-load-gen-uniform-data-100000-samples//results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-28_label-1.csv
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0232s.) Setting batch_size=16.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.5s
# SVR
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   52.4s finished
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_tol  \
# 12       0.115504      0.020407         0.029819        0.010636   0.00272
# 28       0.008886      0.009681         0.002048        0.000260   0.00266
# 4        0.012308      0.006128         0.012188        0.008651   0.00979
# 5        0.054228      0.024478         0.014174        0.009427   0.00514
# 27       0.011103      0.007151         0.002106        0.000042   0.00139
# 29       0.001936      0.000166         0.011396        0.007875     7e-05
# 11       0.001469      0.000165         0.002187        0.001530   0.00388
# 15       0.012704      0.022031         0.003587        0.004120   0.00119
# 18       0.006934      0.006289         0.001874        0.000376   0.00546
# 24       0.004863      0.006412         0.001690        0.000030   0.00021
# 7        0.001926      0.000083         0.005354        0.007333    0.0098
# 21       0.001864      0.000081         0.005084        0.006782    0.0078
# 20       0.002255      0.000104         0.003393        0.003181   0.00745
# 23       0.007504      0.011716         0.003484        0.003454   0.00848
# 19       0.010996      0.011712         0.003557        0.003534   0.00839
# 26       0.001983      0.000167         0.001791        0.000133    0.0066
# 22       0.001826      0.000123         0.009794        0.007155   0.00912
# 14       0.002178      0.000242         0.001477        0.000024   0.00722
# 13       0.004533      0.003645         0.001584        0.000146   0.00795
# 10       0.002239      0.000353         0.002918        0.002721   0.00276
# 9        0.002046      0.000100         0.001481        0.000071   0.00436
# 8        0.001693      0.000265         0.004039        0.004934   0.00981
# 6        0.006824      0.009806         0.007402        0.007772     7e-05
# 3        0.012117      0.013486         0.002250        0.000563   0.00785
# 2        0.006279      0.009695         0.014281        0.025623    0.0029
# 1        0.001720      0.000242         0.002506        0.001835   0.00228
# 17       0.002470      0.000397         0.006840        0.010054    0.0044
# 25       0.007691      0.011272         0.006739        0.006331   0.00504
# 0        0.002469      0.000367         0.001595        0.000088   0.00094
# 16       7.632414      0.272084         2.710802        0.205037   0.00682
#
#    param_kernel param_gamma param_epsilon param_C  \
# 12         poly        auto        0.0074   0.795
# 28       linear        auto        0.0198    3.53
# 4          poly        auto        0.0126   1.885
# 5          poly        auto        0.0158   0.285
# 27         poly        auto        0.0198     4.3
# 29          rbf        auto         0.131    4.21
# 11       linear        auto        0.1916   1.805
# 15         poly       scale        0.1956    0.18
# 18          rbf        auto         0.081   3.765
# 24         poly        auto        0.1472   1.385
# 7       sigmoid        auto        0.1514    1.38
# 21          rbf        auto        0.0326    4.99
# 20          rbf       scale        0.1828   0.135
# 23       linear        auto        0.0282    3.67
# 19         poly       scale        0.0446    3.83
# 26          rbf        auto        0.1908   4.505
# 22       linear       scale        0.0916    1.88
# 14      sigmoid       scale        0.0624    1.59
# 13       linear       scale         0.142    2.67
# 10      sigmoid       scale        0.0492    0.04
# 9       sigmoid       scale        0.1398   1.155
# 8          poly        auto        0.0586    0.63
# 6        linear       scale        0.0374    0.59
# 3        linear        auto        0.1882    3.83
# 2          poly        auto        0.0978   4.415
# 1        linear        auto        0.0616   0.525
# 17         poly       scale        0.1242   1.555
# 25          rbf        auto        0.0968    3.41
# 0          poly       scale        0.0924   2.795
# 16      sigmoid       scale        0.0254   3.305
#
#                                                params  split0_test_r2  \
# 12  {'tol': 0.00272, 'kernel': 'poly', 'gamma': 'a...    8.145952e-01
# 28  {'tol': 0.00266, 'kernel': 'linear', 'gamma': ...    5.183863e-01
# 4   {'tol': 0.00979, 'kernel': 'poly', 'gamma': 'a...    4.693759e-01
# 5   {'tol': 0.00514, 'kernel': 'poly', 'gamma': 'a...    3.926669e-01
# 27  {'tol': 0.00139, 'kernel': 'poly', 'gamma': 'a...    3.049717e-01
# 29  {'tol': 7e-05, 'kernel': 'rbf', 'gamma': 'auto...   -1.778135e-03
# 11  {'tol': 0.00388, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 15  {'tol': 0.00119, 'kernel': 'poly', 'gamma': 's...   -1.778135e-03
# 18  {'tol': 0.00546, 'kernel': 'rbf', 'gamma': 'au...   -1.778135e-03
# 24  {'tol': 0.00021, 'kernel': 'poly', 'gamma': 'a...   -1.778135e-03
# 7   {'tol': 0.0098, 'kernel': 'sigmoid', 'gamma': ...   -1.778135e-03
# 21  {'tol': 0.0078, 'kernel': 'rbf', 'gamma': 'aut...   -1.778135e-03
# 20  {'tol': 0.00745, 'kernel': 'rbf', 'gamma': 'sc...   -1.778135e-03
# 23  {'tol': 0.00848, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 19  {'tol': 0.00839, 'kernel': 'poly', 'gamma': 's...   -1.778135e-03
# 26  {'tol': 0.0066, 'kernel': 'rbf', 'gamma': 'aut...   -1.778135e-03
# 22  {'tol': 0.00912, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 14  {'tol': 0.00722, 'kernel': 'sigmoid', 'gamma':...   -1.778135e-03
# 13  {'tol': 0.00795, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 10  {'tol': 0.00276, 'kernel': 'sigmoid', 'gamma':...   -1.778135e-03
# 9   {'tol': 0.00436, 'kernel': 'sigmoid', 'gamma':...   -1.778135e-03
# 8   {'tol': 0.00981, 'kernel': 'poly', 'gamma': 'a...   -1.778135e-03
# 6   {'tol': 7e-05, 'kernel': 'linear', 'gamma': 's...   -1.778135e-03
# 3   {'tol': 0.00785, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 2   {'tol': 0.0029, 'kernel': 'poly', 'gamma': 'au...   -1.778135e-03
# 1   {'tol': 0.00228, 'kernel': 'linear', 'gamma': ...   -1.778135e-03
# 17  {'tol': 0.0044, 'kernel': 'poly', 'gamma': 'sc...   -1.778135e-03
# 25  {'tol': 0.00504, 'kernel': 'rbf', 'gamma': 'au...   -1.778135e-03
# 0   {'tol': 0.00094, 'kernel': 'poly', 'gamma': 's...   -1.778135e-03
# 16  {'tol': 0.00682, 'kernel': 'sigmoid', 'gamma':...   -3.492024e+08
#
#     split1_test_r2  split2_test_r2  split3_test_r2  split4_test_r2  \
# 12    8.183386e-01    8.186124e-01    8.128765e-01    8.242792e-01
# 28    5.748622e-01    5.231883e-01    5.676386e-01    5.696173e-01
# 4     4.814763e-01    4.909211e-01    4.692659e-01    5.002993e-01
# 5     4.310384e-01    4.287115e-01    4.293276e-01    4.291191e-01
# 27    3.235484e-01    3.368846e-01    2.877338e-01    3.059164e-01
# 29   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 11   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 15   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 18   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 24   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 7    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 21   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 20   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 23   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 19   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 26   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 22   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 14   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 13   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 10   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 9    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 8    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 6    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 3    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 2    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 1    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 17   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 25   -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 0    -8.991823e-03   -8.452062e-03   -3.119825e-03   -5.940400e-03
# 16   -3.760421e+08   -3.765508e+08   -3.633715e+08   -3.851062e+08
#
#     mean_test_r2   std_test_r2  rank_test_r2  split0_test_rmse  \
# 12  8.177404e-01  3.935096e-03             1          0.004161
# 28  5.507385e-01  2.461565e-02             2          0.006706
# 4   4.822677e-01  1.213171e-02             3          0.007039
# 5   4.221727e-01  1.477428e-02             4          0.007530
# 27  3.118110e-01  1.689784e-02             5          0.008056
# 29 -5.656449e-03  2.845930e-03             6          0.009671
# 11 -5.656449e-03  2.845930e-03             6          0.009671
# 15 -5.656449e-03  2.845930e-03             6          0.009671
# 18 -5.656449e-03  2.845930e-03             6          0.009671
# 24 -5.656449e-03  2.845930e-03             6          0.009671
# 7  -5.656449e-03  2.845930e-03             6          0.009671
# 21 -5.656449e-03  2.845930e-03            12          0.009671
# 20 -5.656449e-03  2.845930e-03            12          0.009671
# 23 -5.656449e-03  2.845930e-03            12          0.009671
# 19 -5.656449e-03  2.845930e-03            12          0.009671
# 26 -5.656449e-03  2.845930e-03            12          0.009671
# 22 -5.656449e-03  2.845930e-03            12          0.009671
# 14 -5.656449e-03  2.845930e-03            12          0.009671
# 13 -5.656449e-03  2.845930e-03            12          0.009671
# 10 -5.656449e-03  2.845930e-03            12          0.009671
# 9  -5.656449e-03  2.845930e-03            12          0.009671
# 8  -5.656449e-03  2.845930e-03            12          0.009671
# 6  -5.656449e-03  2.845930e-03            12          0.009671
# 3  -5.656449e-03  2.845930e-03            12          0.009671
# 2  -5.656449e-03  2.845930e-03            12          0.009671
# 1  -5.656449e-03  2.845930e-03            12          0.009671
# 17 -5.656449e-03  2.845930e-03            12          0.009671
# 25 -5.656449e-03  2.845930e-03            28          0.009671
# 0  -5.656449e-03  2.845930e-03            28          0.009671
# 16 -3.700546e+08  1.252262e+07            30        180.568023
#
#     split1_test_rmse  split2_test_rmse  split3_test_rmse  split4_test_rmse  \
# 12          0.004044          0.004057          0.004124          0.003962
# 28          0.006186          0.006578          0.006269          0.006200
# 4           0.006832          0.006797          0.006945          0.006681
# 5           0.007157          0.007200          0.007202          0.007141
# 27          0.007803          0.007758          0.008046          0.007874
# 29          0.009530          0.009567          0.009549          0.009479
# 11          0.009530          0.009567          0.009549          0.009479
# 15          0.009530          0.009567          0.009549          0.009479
# 18          0.009530          0.009567          0.009549          0.009479
# 24          0.009530          0.009567          0.009549          0.009479
# 7           0.009530          0.009567          0.009549          0.009479
# 21          0.009530          0.009567          0.009549          0.009479
# 20          0.009530          0.009567          0.009549          0.009479
# 23          0.009530          0.009567          0.009549          0.009479
# 19          0.009530          0.009567          0.009549          0.009479
# 26          0.009530          0.009567          0.009549          0.009479
# 22          0.009530          0.009567          0.009549          0.009479
# 14          0.009530          0.009567          0.009549          0.009479
# 13          0.009530          0.009567          0.009549          0.009479
# 10          0.009530          0.009567          0.009549          0.009479
# 9           0.009530          0.009567          0.009549          0.009479
# 8           0.009530          0.009567          0.009549          0.009479
# 6           0.009530          0.009567          0.009549          0.009479
# 3           0.009530          0.009567          0.009549          0.009479
# 2           0.009530          0.009567          0.009549          0.009479
# 1           0.009530          0.009567          0.009549          0.009479
# 17          0.009530          0.009567          0.009549          0.009479
# 25          0.009530          0.009567          0.009549          0.009479
# 0           0.009530          0.009567          0.009549          0.009479
# 16        183.985818        184.860608        181.735415        185.472299
#
#     mean_test_rmse  std_test_rmse  rank_test_rmse
# 12        0.004070       0.000069              30
# 28        0.006388       0.000213              29
# 4         0.006859       0.000123              28
# 5         0.007246       0.000144              27
# 27        0.007907       0.000123              26
# 29        0.009559       0.000063              20
# 11        0.009559       0.000063              20
# 15        0.009559       0.000063              20
# 18        0.009559       0.000063              20
# 24        0.009559       0.000063              20
# 7         0.009559       0.000063              20
# 21        0.009559       0.000063               4
# 20        0.009559       0.000063               4
# 23        0.009559       0.000063               4
# 19        0.009559       0.000063               4
# 26        0.009559       0.000063               4
# 22        0.009559       0.000063               4
# 14        0.009559       0.000063               4
# 13        0.009559       0.000063               4
# 10        0.009559       0.000063               4
# 9         0.009559       0.000063               4
# 8         0.009559       0.000063               4
# 6         0.009559       0.000063               4
# 3         0.009559       0.000063               4
# 2         0.009559       0.000063               4
# 1         0.009559       0.000063               4
# 17        0.009559       0.000063               4
# 25        0.009559       0.000063               2
# 0         0.009559       0.000063               2
# 16      183.324432       1.872611               1
# Saving to  ../../pypsa/examples/ieee-13//ieee-13-with-load-gen-uniform-data-100000-samples//results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-29_label-2.csv
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0286s.) Setting batch_size=12.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   59.2s finished
# SVR
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_tol  \
# 18       0.005755      0.006421         0.001983        0.000053   0.00832
# 6        0.005461      0.006291         0.001848        0.000308   0.00537
# 11       0.012232      0.015605         0.002291        0.000066   0.00945
# 0        0.006331      0.005771         0.005299        0.003130   0.00371
# 4        0.001771      0.000106         0.001809        0.000664   0.00492
# 17       0.001619      0.000073         0.002356        0.001703   0.00945
# 22       0.002580      0.001311         0.001676        0.000220   0.00122
# 3        0.014073      0.025276         0.001625        0.000260   0.00981
# 27       0.003702      0.003459         0.010878        0.011736   0.00109
# 25       0.014368      0.025290         0.003580        0.004010   0.00893
# 24       0.001724      0.000382         0.001802        0.000437    0.0033
# 1        0.002949      0.001687         0.005631        0.008324   0.00924
# 13       0.014902      0.021478         0.001729        0.000092   0.00879
# 9        0.008708      0.007653         0.001526        0.000033   0.00908
# 26       0.003213      0.003150         0.012667        0.022113   0.00099
# 23       0.001450      0.000104         0.001576        0.000106   0.00128
# 21       0.001425      0.000093         0.001504        0.000024    0.0041
# 20       0.016211      0.028838         0.001806        0.000236   0.00273
# 19       0.021021      0.029636         0.002028        0.000494   0.00488
# 14       0.005030      0.006867         0.001731        0.000106   0.00113
# 15       0.006542      0.009162         0.003441        0.003463   0.00982
# 28       0.009941      0.015636         0.001555        0.000071   0.00661
# 12       0.002190      0.001367         0.001504        0.000031   0.00916
# 10       0.001696      0.000105         0.003258        0.003230   0.00939
# 7        0.005364      0.003609         0.001724        0.000397   0.00042
# 5        0.010040      0.016719         0.003340        0.003480   0.00469
# 2        0.026600      0.030456         0.001591        0.000107   0.00418
# 16       0.002245      0.000277         0.003258        0.003181   0.00523
# 29       0.001690      0.000112         0.001496        0.000040   0.00952
# 8       13.302559      1.913499         1.908349        0.123905   0.00043
#
#    param_kernel param_gamma param_epsilon param_C  \
# 18      sigmoid        auto        0.0034     4.5
# 6        linear       scale        0.0062   2.255
# 11         poly        auto        0.0044   4.535
# 0           rbf        auto        0.0132   0.825
# 4          poly       scale         0.114    2.68
# 17       linear       scale        0.1102    2.44
# 22          rbf        auto        0.1266   2.985
# 3          poly        auto        0.1666   0.045
# 27      sigmoid        auto        0.1516    3.55
# 25      sigmoid        auto        0.1822    4.55
# 24         poly        auto        0.0914    2.29
# 1           rbf       scale        0.1154   0.305
# 13          rbf       scale         0.182   0.535
# 9           rbf       scale        0.1782    0.71
# 26         poly        auto         0.036    1.16
# 23       linear        auto        0.0946   0.465
# 21       linear        auto        0.1132    1.96
# 20         poly        auto        0.1804   3.605
# 19      sigmoid       scale        0.0374   3.445
# 14       linear        auto        0.1656   0.145
# 15       linear       scale        0.0288   1.135
# 28      sigmoid       scale         0.032    0.11
# 12         poly        auto        0.1952    4.48
# 10         poly       scale        0.0466    3.22
# 7           rbf        auto        0.0628    0.58
# 5        linear       scale        0.0292    3.62
# 2          poly       scale        0.0326   3.925
# 16      sigmoid       scale        0.0576   0.995
# 29          rbf        auto        0.0504   4.915
# 8       sigmoid        auto         0.002   2.915
#
#                                                params  split0_test_r2  \
# 18  {'tol': 0.00832, 'kernel': 'sigmoid', 'gamma':...        0.889542
# 6   {'tol': 0.00537, 'kernel': 'linear', 'gamma': ...        0.863172
# 11  {'tol': 0.00945, 'kernel': 'poly', 'gamma': 'a...        0.693693
# 0   {'tol': 0.00371, 'kernel': 'rbf', 'gamma': 'au...        0.584459
# 4   {'tol': 0.00492, 'kernel': 'poly', 'gamma': 's...       -0.000451
# 17  {'tol': 0.00945, 'kernel': 'linear', 'gamma': ...       -0.000451
# 22  {'tol': 0.00122, 'kernel': 'rbf', 'gamma': 'au...       -0.000451
# 3   {'tol': 0.00981, 'kernel': 'poly', 'gamma': 'a...       -0.000451
# 27  {'tol': 0.00109, 'kernel': 'sigmoid', 'gamma':...       -0.000451
# 25  {'tol': 0.00893, 'kernel': 'sigmoid', 'gamma':...       -0.000451
# 24  {'tol': 0.0033, 'kernel': 'poly', 'gamma': 'au...       -0.000451
# 1   {'tol': 0.00924, 'kernel': 'rbf', 'gamma': 'sc...       -0.000451
# 13  {'tol': 0.00879, 'kernel': 'rbf', 'gamma': 'sc...       -0.000451
# 9   {'tol': 0.00908, 'kernel': 'rbf', 'gamma': 'sc...       -0.000451
# 26  {'tol': 0.00099, 'kernel': 'poly', 'gamma': 'a...       -0.000451
# 23  {'tol': 0.00128, 'kernel': 'linear', 'gamma': ...       -0.000451
# 21  {'tol': 0.0041, 'kernel': 'linear', 'gamma': '...       -0.000451
# 20  {'tol': 0.00273, 'kernel': 'poly', 'gamma': 'a...       -0.000451
# 19  {'tol': 0.00488, 'kernel': 'sigmoid', 'gamma':...       -0.000451
# 14  {'tol': 0.00113, 'kernel': 'linear', 'gamma': ...       -0.000451
# 15  {'tol': 0.00982, 'kernel': 'linear', 'gamma': ...       -0.000451
# 28  {'tol': 0.00661, 'kernel': 'sigmoid', 'gamma':...       -0.000451
# 12  {'tol': 0.00916, 'kernel': 'poly', 'gamma': 'a...       -0.000451
# 10  {'tol': 0.00939, 'kernel': 'poly', 'gamma': 's...       -0.000451
# 7   {'tol': 0.00042, 'kernel': 'rbf', 'gamma': 'au...       -0.000451
# 5   {'tol': 0.00469, 'kernel': 'linear', 'gamma': ...       -0.000451
# 2   {'tol': 0.00418, 'kernel': 'poly', 'gamma': 's...       -0.000451
# 16  {'tol': 0.00523, 'kernel': 'sigmoid', 'gamma':...       -0.000451
# 29  {'tol': 0.00952, 'kernel': 'rbf', 'gamma': 'au...       -0.000451
# 8   {'tol': 0.00043, 'kernel': 'sigmoid', 'gamma':...      -11.401921
#
#     split1_test_r2  split2_test_r2  split3_test_r2  split4_test_r2  \
# 18        0.894697        0.879099        0.889112        0.827409
# 6         0.884669        0.856311        0.863138        0.810326
# 11        0.645213        0.618685        0.703759        0.627574
# 0         0.546266        0.542281        0.548891        0.508517
# 4        -0.038894       -0.024386       -0.029307       -0.053805
# 17       -0.038894       -0.024386       -0.029307       -0.053805
# 22       -0.038894       -0.024386       -0.029307       -0.053805
# 3        -0.038894       -0.024386       -0.029307       -0.053805
# 27       -0.038894       -0.024386       -0.029307       -0.053805
# 25       -0.038894       -0.024386       -0.029307       -0.053805
# 24       -0.038894       -0.024386       -0.029307       -0.053805
# 1        -0.038894       -0.024386       -0.029307       -0.053805
# 13       -0.038894       -0.024386       -0.029307       -0.053805
# 9        -0.038894       -0.024386       -0.029307       -0.053805
# 26       -0.038894       -0.024386       -0.029307       -0.053805
# 23       -0.038894       -0.024386       -0.029307       -0.053805
# 21       -0.038894       -0.024386       -0.029307       -0.053805
# 20       -0.038894       -0.024386       -0.029307       -0.053805
# 19       -0.038894       -0.024386       -0.029307       -0.053805
# 14       -0.038894       -0.024386       -0.029307       -0.053805
# 15       -0.038894       -0.024386       -0.029307       -0.053805
# 28       -0.038894       -0.024386       -0.029307       -0.053805
# 12       -0.038894       -0.024386       -0.029307       -0.053805
# 10       -0.038894       -0.024386       -0.029307       -0.053805
# 7        -0.038894       -0.024386       -0.029307       -0.053805
# 5        -0.038894       -0.024386       -0.029307       -0.053805
# 2        -0.038894       -0.024386       -0.029307       -0.053805
# 16       -0.038894       -0.024386       -0.029307       -0.053805
# 29       -0.038894       -0.024386       -0.029307       -0.053805
# 8       -11.013067      -10.572296       -9.443862      -10.560212
#
#     mean_test_r2  std_test_r2  rank_test_r2  split0_test_rmse  \
# 18      0.875972     0.024801             1          0.002191
# 6       0.855523     0.024533             2          0.002438
# 11      0.657785     0.034648             3          0.003648
# 0       0.546083     0.024109             4          0.004249
# 4      -0.029369     0.017601             5          0.006593
# 17     -0.029369     0.017601             5          0.006593
# 22     -0.029369     0.017601             5          0.006593
# 3      -0.029369     0.017601             5          0.006593
# 27     -0.029369     0.017601             9          0.006593
# 25     -0.029369     0.017601             9          0.006593
# 24     -0.029369     0.017601             9          0.006593
# 1      -0.029369     0.017601             9          0.006593
# 13     -0.029369     0.017601             9          0.006593
# 9      -0.029369     0.017601             9          0.006593
# 26     -0.029369     0.017601            15          0.006593
# 23     -0.029369     0.017601            15          0.006593
# 21     -0.029369     0.017601            15          0.006593
# 20     -0.029369     0.017601            15          0.006593
# 19     -0.029369     0.017601            15          0.006593
# 14     -0.029369     0.017601            15          0.006593
# 15     -0.029369     0.017601            15          0.006593
# 28     -0.029369     0.017601            15          0.006593
# 12     -0.029369     0.017601            15          0.006593
# 10     -0.029369     0.017601            15          0.006593
# 7      -0.029369     0.017601            15          0.006593
# 5      -0.029369     0.017601            15          0.006593
# 2      -0.029369     0.017601            15          0.006593
# 16     -0.029369     0.017601            15          0.006593
# 29     -0.029369     0.017601            15          0.006593
# 8     -10.598272     0.656154            30          0.023213
#
#     split1_test_rmse  split2_test_rmse  split3_test_rmse  split4_test_rmse  \
# 18          0.002118          0.002238          0.002177          0.002727
# 6           0.002217          0.002440          0.002419          0.002859
# 11          0.003888          0.003975          0.003559          0.004006
# 0           0.004396          0.004355          0.004392          0.004602
# 4           0.006653          0.006515          0.006634          0.006739
# 17          0.006653          0.006515          0.006634          0.006739
# 22          0.006653          0.006515          0.006634          0.006739
# 3           0.006653          0.006515          0.006634          0.006739
# 27          0.006653          0.006515          0.006634          0.006739
# 25          0.006653          0.006515          0.006634          0.006739
# 24          0.006653          0.006515          0.006634          0.006739
# 1           0.006653          0.006515          0.006634          0.006739
# 13          0.006653          0.006515          0.006634          0.006739
# 9           0.006653          0.006515          0.006634          0.006739
# 26          0.006653          0.006515          0.006634          0.006739
# 23          0.006653          0.006515          0.006634          0.006739
# 21          0.006653          0.006515          0.006634          0.006739
# 20          0.006653          0.006515          0.006634          0.006739
# 19          0.006653          0.006515          0.006634          0.006739
# 14          0.006653          0.006515          0.006634          0.006739
# 15          0.006653          0.006515          0.006634          0.006739
# 28          0.006653          0.006515          0.006634          0.006739
# 12          0.006653          0.006515          0.006634          0.006739
# 10          0.006653          0.006515          0.006634          0.006739
# 7           0.006653          0.006515          0.006634          0.006739
# 5           0.006653          0.006515          0.006634          0.006739
# 2           0.006653          0.006515          0.006634          0.006739
# 16          0.006653          0.006515          0.006634          0.006739
# 29          0.006653          0.006515          0.006634          0.006739
# 8           0.022622          0.021896          0.021131          0.022321
#
#     mean_test_rmse  std_test_rmse  rank_test_rmse
# 18        0.002290       0.000222              30
# 6         0.002475       0.000210              29
# 11        0.003815       0.000179              28
# 0         0.004399       0.000115              27
# 4         0.006627       0.000074              23
# 17        0.006627       0.000074              23
# 22        0.006627       0.000074              23
# 3         0.006627       0.000074              23
# 27        0.006627       0.000074               2
# 25        0.006627       0.000074               2
# 24        0.006627       0.000074               2
# 1         0.006627       0.000074               2
# 13        0.006627       0.000074               2
# 9         0.006627       0.000074               2
# 26        0.006627       0.000074               2
# 23        0.006627       0.000074               2
# 21        0.006627       0.000074               2
# 20        0.006627       0.000074               2
# 19        0.006627       0.000074               2
# 14        0.006627       0.000074               2
# 15        0.006627       0.000074               2
# 28        0.006627       0.000074               2
# 12        0.006627       0.000074               2
# 10        0.006627       0.000074               2
# 7         0.006627       0.000074               2
# 5         0.006627       0.000074               2
# 2         0.006627       0.000074               2
# 16        0.006627       0.000074               2
# 29        0.006627       0.000074               2
# 8         0.022236       0.000700               1
# Saving to  ../../pypsa/examples/ieee-13//ieee-13-with-load-gen-uniform-data-100000-samples//results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-30_label-3.csv
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0445s.) Setting batch_size=8.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   44.4s finished
# SVR
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_tol  \
# 19       0.013276      0.016070         0.004238        0.003859   0.00745
# 4        0.005235      0.003163         0.001768        0.000074   0.00902
# 3        0.009786      0.007380         0.007339        0.011214   0.00198
# 0        0.018313      0.021273         0.007712        0.009855    0.0016
# 2        0.009030      0.014877         0.001640        0.000171   0.00848
# 26       0.005439      0.007841         0.001648        0.000361   0.00579
# 25       0.001737      0.000158         0.006421        0.005977   0.00556
# 15       0.001644      0.000070         0.008793        0.010992   0.00539
# 12       0.003947      0.004238         0.004916        0.006776   0.00016
# 18       0.001555      0.000198         0.004656        0.003986   0.00794
# 20       0.006030      0.005072         0.001505        0.000049   0.00339
# 23       0.005990      0.007998         0.004848        0.006309   0.00287
# 22       0.002120      0.000382         0.001513        0.000043   0.00279
# 24       0.003448      0.003191         0.003248        0.003498   0.00529
# 27       0.001719      0.000232         0.001653        0.000204   0.00635
# 21       0.016322      0.024684         0.001564        0.000098   0.00044
# 17       0.004748      0.006368         0.006556        0.010047    0.0043
# 14       0.005668      0.008031         0.007274        0.011445    0.0098
# ...
# 2         0.010791       0.000129               4
# 15        0.010791       0.000129               4
# 0         0.010791       0.000129               1
# 21        0.010791       0.000129               1
# 24        0.010791       0.000129               1
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0169s.) Setting batch_size=22.
# Saving to  ../../pypsa/examples/ieee-13//ieee-13-with-load-gen-uniform-data-100000-samples//results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-33_label-9.csv
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.1s
# SVR
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:   53.4s finished
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time param_tol  \
# 27       0.098756      0.007213         0.037678        0.012196   0.00609
# 8        0.002630      0.000809         0.012323        0.008823    0.0045
# 6        3.984733      1.849278         0.056195        0.020153    0.0077
# 20       0.019444      0.016742         0.001627        0.000077   0.00427
# 26       0.009184      0.010898         0.003199        0.003196   0.00448
# 24       0.001839      0.000322         0.008817        0.010807   0.00286
# 4        0.004069      0.004874         0.001602        0.000031   0.00819
# 18       0.006198      0.005101         0.005284        0.006706   0.00813
# 16       0.008203      0.007823         0.001620        0.000021   0.00538
# 28       0.006503      0.009693         0.004765        0.006335   0.00564
# 0        0.001987      0.000279         0.002677        0.001802   0.00596
# 23       0.003428      0.003186         0.003110        0.003245   0.00493
# 22       0.006943      0.006467         0.007340        0.011563   0.00708
# 21       0.012699      0.022148         0.004719        0.006387   0.00934
# 19       0.001523      0.000040         0.008055        0.009553    0.0027
# 14       0.001873      0.000215         0.003256        0.003196    0.0098
# 13       0.004873      0.006362         0.007255        0.011238   0.00087
# 11       0.004617      0.006404         0.006319        0.009627   0.00346
# 10       0.001748      0.000326         0.008875        0.011214   0.00011
# 7        0.004014      0.003518         0.008273        0.008121   0.00532
# 5        0.004482      0.004792         0.007472        0.011311   0.00946
# 3        0.002151      0.000428         0.011147        0.013750   0.00959
# 1        0.002623      0.001077         0.002549        0.001561   0.00497
# 25       0.008408      0.007893         0.001480        0.000061    0.0029
# 29       0.003121      0.003279         0.004764        0.006348   0.00331
# 9        0.015976      0.021519         0.004725        0.006394   0.00625
# 17       0.003451      0.003421         0.007501        0.011534   0.00344
# 12       0.002008      0.000183         0.003179        0.003234   0.00096
# 15       0.005731      0.007997         0.008434        0.010049   0.00988
# 2        7.878410      0.523547         2.736991        0.104263   0.00036
#
#    param_kernel param_gamma param_epsilon param_C  \
# 27          rbf       scale        0.0044    0.92
# 8        linear       scale        0.0106   3.965
# 6          poly       scale         0.007   2.805
# 20       linear       scale        0.0282    0.08
# 26          rbf       scale        0.1948    2.26
# 24      sigmoid        auto        0.1988    4.41
# 4       sigmoid        auto        0.1244   2.595
# 18          rbf       scale        0.1566   3.545
# 16       linear       scale        0.1928    4.82
# 28       linear       scale        0.1464   2.345
# 0        linear       scale        0.1352    1.95
# 23          rbf        auto        0.1858   1.195
# 22      sigmoid       scale         0.135   1.455
# 21       linear       scale        0.0716       4
# 19       linear        auto        0.0768   2.685
# 14          rbf        auto        0.1632    1.35
# 13       linear       scale        0.1144   2.125
# 11         poly        auto        0.0602    4.51
# 10      sigmoid        auto        0.1068     1.7
# 7           rbf       scale        0.0908    4.03
# 5           rbf       scale        0.0802   0.895
# 3        linear       scale        0.1632    1.54
# 1           rbf       scale        0.0784    1.46
# 25      sigmoid       scale        0.1622    0.04
# 29       linear        auto        0.1382    2.93
# 9        linear       scale        0.1738   2.515
# 17       linear       scale        0.1178     4.7
# 12          rbf       scale        0.1116     4.1
# 15       linear        auto        0.1862   0.145
# 2       sigmoid       scale        0.0094    1.77
#
#                                                params  split0_test_r2  \
# 27  {'tol': 0.00609, 'kernel': 'rbf', 'gamma': 'sc...    9.590252e-01
# 8   {'tol': 0.0045, 'kernel': 'linear', 'gamma': '...    9.102947e-01
# 6   {'tol': 0.0077, 'kernel': 'poly', 'gamma': 'sc...    8.694605e-01
# 20  {'tol': 0.00427, 'kernel': 'linear', 'gamma': ...    3.878715e-01
# 26  {'tol': 0.00448, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 24  {'tol': 0.00286, 'kernel': 'sigmoid', 'gamma':...   -3.278980e-04
# 4   {'tol': 0.00819, 'kernel': 'sigmoid', 'gamma':...   -3.278980e-04
# 18  {'tol': 0.00813, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 16  {'tol': 0.00538, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 28  {'tol': 0.00564, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 0   {'tol': 0.00596, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 23  {'tol': 0.00493, 'kernel': 'rbf', 'gamma': 'au...   -3.278980e-04
# 22  {'tol': 0.00708, 'kernel': 'sigmoid', 'gamma':...   -3.278980e-04
# 21  {'tol': 0.00934, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 19  {'tol': 0.0027, 'kernel': 'linear', 'gamma': '...   -3.278980e-04
# 14  {'tol': 0.0098, 'kernel': 'rbf', 'gamma': 'aut...   -3.278980e-04
# 13  {'tol': 0.00087, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 11  {'tol': 0.00346, 'kernel': 'poly', 'gamma': 'a...   -3.278980e-04
# 10  {'tol': 0.00011, 'kernel': 'sigmoid', 'gamma':...   -3.278980e-04
# 7   {'tol': 0.00532, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 5   {'tol': 0.00946, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 3   {'tol': 0.00959, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 1   {'tol': 0.00497, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 25  {'tol': 0.0029, 'kernel': 'sigmoid', 'gamma': ...   -3.278980e-04
# 29  {'tol': 0.00331, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 9   {'tol': 0.00625, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 17  {'tol': 0.00344, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 12  {'tol': 0.00096, 'kernel': 'rbf', 'gamma': 'sc...   -3.278980e-04
# 15  {'tol': 0.00988, 'kernel': 'linear', 'gamma': ...   -3.278980e-04
# 2   {'tol': 0.00036, 'kernel': 'sigmoid', 'gamma':...   -7.314165e+07
#
#     split1_test_r2  split2_test_r2  split3_test_r2  split4_test_r2  \
# 27    9.479428e-01    9.458033e-01    9.561350e-01    9.543787e-01
# 8     9.050132e-01    9.148957e-01    8.724264e-01    9.057316e-01
# 6     8.473473e-01    8.574252e-01    8.626727e-01    8.904726e-01
# 20    3.774061e-01    3.755827e-01    3.767320e-01    3.951338e-01
# 26   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 24   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 4    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 18   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 16   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 28   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 0    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 23   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 22   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 21   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 19   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 14   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 13   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 11   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 10   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 7    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 5    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 3    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 1    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 25   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 29   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 9    -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 17   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 12   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 15   -1.732524e-02   -1.086651e-02   -1.612904e-02   -1.754430e-02
# 2    -7.679356e+07   -8.099347e+07   -7.490977e+07   -7.616489e+07
#
#     mean_test_r2   std_test_r2  rank_test_r2  split0_test_rmse  \
# 27  9.526570e-01  4.996237e-03             1          0.002289
# 8   9.016723e-01  1.504768e-02             2          0.003387
# 6   8.654757e-01  1.443627e-02             3          0.004086
# 20  3.825452e-01  7.687934e-03             4          0.008847
# 26 -1.243860e-02  6.522383e-03             5          0.011310
# 24 -1.243860e-02  6.522383e-03             5          0.011310
# 4  -1.243860e-02  6.522383e-03             5          0.011310
# 18 -1.243860e-02  6.522383e-03             5          0.011310
# 16 -1.243860e-02  6.522383e-03             5          0.011310
# 28 -1.243860e-02  6.522383e-03             5          0.011310
# 0  -1.243860e-02  6.522383e-03            11          0.011310
# 23 -1.243860e-02  6.522383e-03            11          0.011310
# 22 -1.243860e-02  6.522383e-03            11          0.011310
# 21 -1.243860e-02  6.522383e-03            11          0.011310
# 19 -1.243860e-02  6.522383e-03            11          0.011310
# 14 -1.243860e-02  6.522383e-03            11          0.011310
# 13 -1.243860e-02  6.522383e-03            11          0.011310
# 11 -1.243860e-02  6.522383e-03            11          0.011310
# 10 -1.243860e-02  6.522383e-03            11          0.011310
# 7  -1.243860e-02  6.522383e-03            11          0.011310
# 5  -1.243860e-02  6.522383e-03            11          0.011310
# 3  -1.243860e-02  6.522383e-03            11          0.011310
# 1  -1.243860e-02  6.522383e-03            11          0.011310
# 25 -1.243860e-02  6.522383e-03            24          0.011310
# 29 -1.243860e-02  6.522383e-03            24          0.011310
# 9  -1.243860e-02  6.522383e-03            26          0.011310
# 17 -1.243860e-02  6.522383e-03            27          0.011310
# 12 -1.243860e-02  6.522383e-03            27          0.011310
# 15 -1.243860e-02  6.522383e-03            27          0.011310
# 2  -7.640067e+07  2.613340e+06            30         96.709041
#
#     split1_test_rmse  split2_test_rmse  split3_test_rmse  split4_test_rmse  \
# 27          0.002566          0.002561          0.002355          0.002431
# 8           0.003466          0.003209          0.004017          0.003495
# 6           0.004393          0.004154          0.004167          0.003767
# 20          0.008873          0.008693          0.008878          0.008852
# 26          0.011342          0.011061          0.011336          0.011482
# 24          0.011342          0.011061          0.011336          0.011482
# 4           0.011342          0.011061          0.011336          0.011482
# 18          0.011342          0.011061          0.011336          0.011482
# 16          0.011342          0.011061          0.011336          0.011482
# 28          0.011342          0.011061          0.011336          0.011482
# 0           0.011342          0.011061          0.011336          0.011482
# 23          0.011342          0.011061          0.011336          0.011482
# 22          0.011342          0.011061          0.011336          0.011482
# 21          0.011342          0.011061          0.011336          0.011482
# 19          0.011342          0.011061          0.011336          0.011482
# 14          0.011342          0.011061          0.011336          0.011482
# 13          0.011342          0.011061          0.011336          0.011482
# 11          0.011342          0.011061          0.011336          0.011482
# 10          0.011342          0.011061          0.011336          0.011482
# 7           0.011342          0.011061          0.011336          0.011482
# 5           0.011342          0.011061          0.011336          0.011482
# 3           0.011342          0.011061          0.011336          0.011482
# 1           0.011342          0.011061          0.011336          0.011482
# 25          0.011342          0.011061          0.011336          0.011482
# 29          0.011342          0.011061          0.011336          0.011482
# 9           0.011342          0.011061          0.011336          0.011482
# 17          0.011342          0.011061          0.011336          0.011482
# 12          0.011342          0.011061          0.011336          0.011482
# 15          0.011342          0.011061          0.011336          0.011482
# 2          98.539410         99.007753         97.332326         99.335754
#
#     mean_test_rmse  std_test_rmse  rank_test_rmse
# 27        0.002440       0.000110              30
# 8         0.003515       0.000270              29
# 6         0.004113       0.000202              28
# 20        0.008829       0.000069              27
# 26        0.011306       0.000136              21
# 24        0.011306       0.000136              21
# 4         0.011306       0.000136              21
# 18        0.011306       0.000136              21
# 16        0.011306       0.000136              21
# 28        0.011306       0.000136              21
# 0         0.011306       0.000136               6
# 23        0.011306       0.000136               6
# 22        0.011306       0.000136               6
# 21        0.011306       0.000136               6
# 19        0.011306       0.000136               6
# 14        0.011306       0.000136               6
# 13        0.011306       0.000136               6
# 11        0.011306       0.000136               6
# 10        0.011306       0.000136               6
# 7         0.011306       0.000136               6
# 5         0.011306       0.000136               6
# 3         0.011306       0.000136               6
# 1         0.011306       0.000136               6
# 25        0.011306       0.000136               6
# 29        0.011306       0.000136               6
# 9         0.011306       0.000136               2
# 17        0.011306       0.000136               2
# 12        0.011306       0.000136               2
# 15        0.011306       0.000136               2
# 2        98.184857       1.003222               1
# Saving to  ../../pypsa/examples/ieee-13//ieee-13-with-load-gen-uniform-data-100000-samples//results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-34_label-10.csv
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Batch computation too fast (0.0124s.) Setting batch_size=32.
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 118 tasks      | elapsed:    2.7s

# %%
# for reading values if you closed the notebook
# filepath = (path_to_powerflow_data +
#            "/results/approximating_with_svr_grid_results-10000_samples-2019-09-12-21-08_label-12.csv")
imported_results = pd.read_csv(filepath)
display(imported_results.sort_values(by=["rank_test_r2"]))
# Out:
#    Unnamed: 0  mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 6           6       0.004027      0.003173         0.001795        0.000185
# 4           4       0.002008      0.000317         0.008344        0.008668
# 1           1       0.001963      0.000263         0.001557        0.000138
# 0           0       0.003453      0.001175         0.003422        0.003401
# 2           2       0.002120      0.000141         0.008455        0.013998
# 7           7       0.002677      0.001642         0.011723        0.015116
# 8           8       0.004473      0.004843         0.001540        0.000016
# 9           9       0.005063      0.006830         0.004357        0.004945
# 5           5       0.002014      0.000119         0.001459        0.000043
# 3           3       0.001501      0.000087         0.001492        0.000031
#
#    param_tol param_kernel param_gamma  param_epsilon  param_C  \
# 6    0.00641          rbf        auto         0.0282    3.230
# 4    0.00824         poly       scale         0.0242    4.630
# 1    0.00140         poly       scale         0.0940    0.065
# 0    0.00255      sigmoid       scale         0.1110    3.310
# 2    0.00009      sigmoid       scale         0.0562    3.900
# 7    0.00645          rbf       scale         0.0504    3.740
# 8    0.00577      sigmoid       scale         0.1376    0.570
# 9    0.00539         poly        auto         0.0604    3.990
# 5    0.00650      sigmoid       scale         0.0926    0.080
# 3    0.00682         poly        auto         0.1702    3.685
#
#                                               params  split0_test_r2  \
# 6  {'tol': 0.00641, 'kernel': 'rbf', 'gamma': 'au...        0.300632
# 4  {'tol': 0.00824, 'kernel': 'poly', 'gamma': 's...        0.092631
# 1  {'tol': 0.0014, 'kernel': 'poly', 'gamma': 'sc...       -0.000622
# 0  {'tol': 0.00255, 'kernel': 'sigmoid', 'gamma':...       -0.000622
# 2  {'tol': 9e-05, 'kernel': 'sigmoid', 'gamma': '...       -0.000622
# 7  {'tol': 0.00645, 'kernel': 'rbf', 'gamma': 'sc...       -0.000622
# 8  {'tol': 0.00577, 'kernel': 'sigmoid', 'gamma':...       -0.000622
# 9  {'tol': 0.00539, 'kernel': 'poly', 'gamma': 'a...       -0.000622
# 5  {'tol': 0.0065, 'kernel': 'sigmoid', 'gamma': ...       -0.000622
# 3  {'tol': 0.00682, 'kernel': 'poly', 'gamma': 'a...       -0.000622
#
#    split1_test_r2  split2_test_r2  split3_test_r2  split4_test_r2  \
# 6        0.321616        0.320192        0.323132        0.325418
# 4        0.283887        0.244285        0.276795        0.296674
# 1       -0.016433       -0.009225       -0.014644       -0.019426
# 0       -0.016433       -0.009225       -0.014644       -0.019426
# 2       -0.016433       -0.009225       -0.014644       -0.019426
# 7       -0.016433       -0.009225       -0.014644       -0.019426
# 8       -0.016433       -0.009225       -0.014644       -0.019426
# 9       -0.016433       -0.009225       -0.014644       -0.019426
# 5       -0.016433       -0.009225       -0.014644       -0.019426
# 3       -0.016433       -0.009225       -0.014644       -0.019426
#
#    mean_test_r2  std_test_r2  rank_test_r2  split0_test_rmse  \
# 6      0.318198     0.008952             1          0.009030
# 4      0.238855     0.075128             2          0.010286
# 1     -0.012070     0.006617             3          0.010801
# 0     -0.012070     0.006617             4          0.010801
# 2     -0.012070     0.006617             4          0.010801
# 7     -0.012070     0.006617             4          0.010801
# 8     -0.012070     0.006617             4          0.010801
# 9     -0.012070     0.006617             4          0.010801
# 5     -0.012070     0.006617             9          0.010801
# 3     -0.012070     0.006617            10          0.010801
#
#    split1_test_rmse  split2_test_rmse  split3_test_rmse  split4_test_rmse  \
# 6          0.008841          0.008676          0.008804          0.008927
# 4          0.009083          0.009148          0.009100          0.009115
# 1          0.010821          0.010571          0.010779          0.010974
# 0          0.010821          0.010571          0.010779          0.010974
# 2          0.010821          0.010571          0.010779          0.010974
# 7          0.010821          0.010571          0.010779          0.010974
# 8          0.010821          0.010571          0.010779          0.010974
# 9          0.010821          0.010571          0.010779          0.010974
# 5          0.010821          0.010571          0.010779          0.010974
# 3          0.010821          0.010571          0.010779          0.010974
#
#    mean_test_rmse  std_test_rmse  rank_test_rmse
# 6        0.008856       0.000119              10
# 4        0.009346       0.000470               9
# 1        0.010789       0.000129               8
# 0        0.010789       0.000129               2
# 2        0.010789       0.000129               2
# 7        0.010789       0.000129               2
# 8        0.010789       0.000129               2
# 9        0.010789       0.000129               2
# 5        0.010789       0.000129               2
# 3        0.010789       0.000129               1
